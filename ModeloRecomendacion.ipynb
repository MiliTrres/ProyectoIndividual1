# %% [markdown]
# ## Modelado de Datos para Funciones de Machine Learning

# %% [markdown]
# Importación de librerias necesarias:

# %%
import pandas as pd
import numpy as np
import ast
import FuncionExtra as f

import scipy as sp
from sklearn.metrics.pairwise import cosine_similarity
import operator

#import pyarrow as pa
#import pyarrow.parquet as pq

# %% [markdown]
# ### Modelo de recomendación item - item:

# %% [markdown]
# Generamos un modelo de recomendación en base a las **tags** de cada item.

# %%
steam_games = pd.read_csv('steam_games_limpio.csv', encoding='utf-8')

# %%
steam_games.drop_duplicates(subset= 'id', inplace= True)

# %% [markdown]
# Extraemos solo las columnas que utilizaremos para nuestro modelo de recomendación:

# %%
steam_games = steam_games[['id', 'app_name', 'tags']]

# %% [markdown]
# Visualizamos el DataFrame resultante:

# %%
steam_games
# Out:
#              id                  app_name  \
# 0      761140.0       Lost Summoner Kitty
# 5      643980.0                 Ironbound
# 9      670290.0   Real Pool 3D - Poolians
# 14     767400.0                   弹炸人2222
# 17     773570.0             Log Challenge
# ...         ...                       ...
# 74821  773640.0            Colony On Mars
# 74825  733530.0  LOGistICAL: South Africa
# 74828  610660.0             Russian Roads
# 74831  658870.0       EXIT 2 - Directions
# 74833  681550.0               Maze Run VR
#
#                                                     tags
# 0      ['Strategy', 'Action', 'Indie', 'Casual', 'Sim...
# 5      ['Free to Play', 'Strategy', 'Indie', 'RPG', '...
# 9      ['Free to Play', 'Simulation', 'Sports', 'Casu...
# 14                     ['Action', 'Adventure', 'Casual']
# 17               ['Action', 'Indie', 'Casual', 'Sports']
# ...                                                  ...
# 74821      ['Strategy', 'Indie', 'Casual', 'Simulation']
# 74825                    ['Strategy', 'Indie', 'Casual']
# 74828                  ['Indie', 'Simulation', 'Racing']
# 74831  ['Indie', 'Casual', 'Puzzle', 'Singleplayer', ...
# 74833  ['Early Access', 'Adventure', 'Indie', 'Action...
#
# [32133 rows x 3 columns]

# %% [markdown]
# Información general:

# %%
steam_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32133 entries, 0 to 74833
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        32132 non-null  float64
#  1   app_name  32131 non-null  object
#  2   tags      31970 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 1004.2+ KB

# %% [markdown]
# Porcentaje de nulos:

# %%
f.porcentaje_valores_nulos(steam_games)
# Out:
# La columna id tiene un  0.00 % de valores nulos
# La columna app_name tiene un  0.01 % de valores nulos
# La columna tags tiene un  0.51 % de valores nulos

# %%
steam_games
# Out:
#              id                  app_name  \
# 0      761140.0       Lost Summoner Kitty
# 5      643980.0                 Ironbound
# 9      670290.0   Real Pool 3D - Poolians
# 14     767400.0                   弹炸人2222
# 17     773570.0             Log Challenge
# ...         ...                       ...
# 74821  773640.0            Colony On Mars
# 74825  733530.0  LOGistICAL: South Africa
# 74828  610660.0             Russian Roads
# 74831  658870.0       EXIT 2 - Directions
# 74833  681550.0               Maze Run VR
#
#                                                     tags
# 0      ['Strategy', 'Action', 'Indie', 'Casual', 'Sim...
# 5      ['Free to Play', 'Strategy', 'Indie', 'RPG', '...
# 9      ['Free to Play', 'Simulation', 'Sports', 'Casu...
# 14                     ['Action', 'Adventure', 'Casual']
# 17               ['Action', 'Indie', 'Casual', 'Sports']
# ...                                                  ...
# 74821      ['Strategy', 'Indie', 'Casual', 'Simulation']
# 74825                    ['Strategy', 'Indie', 'Casual']
# 74828                  ['Indie', 'Simulation', 'Racing']
# 74831  ['Indie', 'Casual', 'Puzzle', 'Singleplayer', ...
# 74833  ['Early Access', 'Adventure', 'Indie', 'Action...
#
# [32133 rows x 3 columns]

# %% [markdown]
# Eliminamos los nulos, por más que su porcentaje sea bajo:

# %%
steam_games = steam_games.dropna()

# %% [markdown]
# Vemos el tipo de dato de la columna **tags**:

# %%
type(steam_games['tags'][0])
# Out:
# str

# %% [markdown]
# Lo cambiamos a lista:

# %%
steam_games['tags'] = steam_games['tags'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [])
# Out:
# <ipython-input-38-74c142a332fe>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   steam_games['tags'] = steam_games['tags'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [])

# %% [markdown]
# Verificamos:

# %%
type(steam_games['tags'][0])
# Out:
# list

# %% [markdown]
# Separamos las etiquetas:

# %%
games = steam_games['tags'].apply(lambda x: ','.join(map(str, x)))
games = games.str.split(',', expand=True)

# %% [markdown]
# Verificamos:

# %%
games
# Out:
#                  0           1       2             3            4   \
# 0          Strategy      Action   Indie        Casual   Simulation
# 5      Free to Play    Strategy   Indie           RPG    Card Game
# 9      Free to Play  Simulation  Sports        Casual        Indie
# 14           Action   Adventure  Casual          None         None
# 17           Action       Indie  Casual        Sports         None
# ...             ...         ...     ...           ...          ...
# 74821      Strategy       Indie  Casual    Simulation         None
# 74825      Strategy       Indie  Casual          None         None
# 74828         Indie  Simulation  Racing          None         None
# 74831         Indie      Casual  Puzzle  Singleplayer  Atmospheric
# 74833  Early Access   Adventure   Indie        Action   Simulation
#
#                       5           6        7         8             9   \
# 0                   None        None     None      None          None
# 5      Trading Card Game  Turn-Based  Fantasy  Tactical  Dark Fantasy
# 9            Multiplayer        None     None      None          None
# 14                  None        None     None      None          None
# 17                  None        None     None      None          None
# ...                  ...         ...      ...       ...           ...
# 74821               None        None     None      None          None
# 74825               None        None     None      None          None
# 74828               None        None     None      None          None
# 74831           Relaxing        None     None      None          None
# 74833                 VR        None     None      None          None
#
#                10    11    12           13            14  \
# 0            None  None  None         None          None
# 5      Board Game   PvP    2D  Competitive  Replay Value
# 9            None  None  None         None          None
# 14           None  None  None         None          None
# 17           None  None  None         None          None
# ...           ...   ...   ...          ...           ...
# 74821        None  None  None         None          None
# 74825        None  None  None         None          None
# 74828        None  None  None         None          None
# 74831        None  None  None         None          None
# 74833        None  None  None         None          None
#
#                             15                  16         17  \
# 0                         None                None       None
# 5      Character Customization  Female Protagonist  Difficult
# 9                         None                None       None
# 14                        None                None       None
# 17                        None                None       None
# ...                        ...                 ...        ...
# 74821                     None                None       None
# 74825                     None                None       None
# 74828                     None                None       None
# 74831                     None                None       None
# 74833                     None                None       None
#
#                           18    19
# 0                       None  None
# 5      Design & Illustration  None
# 9                       None  None
# 14                      None  None
# 17                      None  None
# ...                      ...   ...
# 74821                   None  None
# 74825                   None  None
# 74828                   None  None
# 74831                   None  None
# 74833                   None  None
#
# [31969 rows x 20 columns]

# %% [markdown]
# Generamos Dummies:

# %%
games = pd.get_dummies(games)

# %%
games
# Out:
#        0_2D  0_2D Fighter  0_360 Video  0_3D Platformer  0_4 Player Local  \
# 0         0             0            0                0                 0
# 5         0             0            0                0                 0
# 9         0             0            0                0                 0
# 14        0             0            0                0                 0
# 17        0             0            0                0                 0
# ...     ...           ...          ...              ...               ...
# 74821     0             0            0                0                 0
# 74825     0             0            0                0                 0
# 74828     0             0            0                0                 0
# 74831     0             0            0                0                 0
# 74833     0             0            0                0                 0
#
#        0_4X  0_Action  0_Action RPG  0_Adventure  0_America  ...  \
# 0         0         0             0            0          0  ...
# 5         0         0             0            0          0  ...
# 9         0         0             0            0          0  ...
# 14        0         1             0            0          0  ...
# 17        0         1             0            0          0  ...
# ...     ...       ...           ...          ...        ...  ...
# 74821     0         0             0            0          0  ...
# 74825     0         0             0            0          0  ...
# 74828     0         0             0            0          0  ...
# 74831     0         0             0            0          0  ...
# 74833     0         0             0            0          0  ...
#
#        19_Underwater  19_Utilities  19_VR  19_Video Production  19_Violent  \
# 0                  0             0      0                    0           0
# 5                  0             0      0                    0           0
# 9                  0             0      0                    0           0
# 14                 0             0      0                    0           0
# 17                 0             0      0                    0           0
# ...              ...           ...    ...                  ...         ...
# 74821              0             0      0                    0           0
# 74825              0             0      0                    0           0
# 74828              0             0      0                    0           0
# 74831              0             0      0                    0           0
# 74833              0             0      0                    0           0
#
#        19_Visual Novel  19_Voxel  19_Walking Simulator  19_Wargame  19_Zombies
# 0                    0         0                     0           0           0
# 5                    0         0                     0           0           0
# 9                    0         0                     0           0           0
# 14                   0         0                     0           0           0
# 17                   0         0                     0           0           0
# ...                ...       ...                   ...         ...         ...
# 74821                0         0                     0           0           0
# 74825                0         0                     0           0           0
# 74828                0         0                     0           0           0
# 74831                0         0                     0           0           0
# 74833                0         0                     0           0           0
#
# [31969 rows x 5454 columns]

# %% [markdown]
# Concatenamos ambos DataFrames:

# %%
steam_games_final = pd.concat([steam_games, games], axis= 1)

# %%
steam_games_final
# Out:
#              id                  app_name  \
# 0      761140.0       Lost Summoner Kitty
# 5      643980.0                 Ironbound
# 9      670290.0   Real Pool 3D - Poolians
# 14     767400.0                   弹炸人2222
# 17     773570.0             Log Challenge
# ...         ...                       ...
# 74821  773640.0            Colony On Mars
# 74825  733530.0  LOGistICAL: South Africa
# 74828  610660.0             Russian Roads
# 74831  658870.0       EXIT 2 - Directions
# 74833  681550.0               Maze Run VR
#
#                                                     tags  0_2D  0_2D Fighter  \
# 0          [Strategy, Action, Indie, Casual, Simulation]     0             0
# 5      [Free to Play, Strategy, Indie, RPG, Card Game...     0             0
# 9      [Free to Play, Simulation, Sports, Casual, Ind...     0             0
# 14                           [Action, Adventure, Casual]     0             0
# 17                       [Action, Indie, Casual, Sports]     0             0
# ...                                                  ...   ...           ...
# 74821              [Strategy, Indie, Casual, Simulation]     0             0
# 74825                          [Strategy, Indie, Casual]     0             0
# 74828                        [Indie, Simulation, Racing]     0             0
# 74831  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...     0             0
# 74833  [Early Access, Adventure, Indie, Action, Simul...     0             0
#
#        0_360 Video  0_3D Platformer  0_4 Player Local  0_4X  0_Action  ...  \
# 0                0                0                 0     0         0  ...
# 5                0                0                 0     0         0  ...
# 9                0                0                 0     0         0  ...
# 14               0                0                 0     0         1  ...
# 17               0                0                 0     0         1  ...
# ...            ...              ...               ...   ...       ...  ...
# 74821            0                0                 0     0         0  ...
# 74825            0                0                 0     0         0  ...
# 74828            0                0                 0     0         0  ...
# 74831            0                0                 0     0         0  ...
# 74833            0                0                 0     0         0  ...
#
#        19_Underwater  19_Utilities  19_VR  19_Video Production  19_Violent  \
# 0                  0             0      0                    0           0
# 5                  0             0      0                    0           0
# 9                  0             0      0                    0           0
# 14                 0             0      0                    0           0
# 17                 0             0      0                    0           0
# ...              ...           ...    ...                  ...         ...
# 74821              0             0      0                    0           0
# 74825              0             0      0                    0           0
# 74828              0             0      0                    0           0
# 74831              0             0      0                    0           0
# 74833              0             0      0                    0           0
#
#        19_Visual Novel  19_Voxel  19_Walking Simulator  19_Wargame  19_Zombies
# 0                    0         0                     0           0           0
# 5                    0         0                     0           0           0
# 9                    0         0                     0           0           0
# 14                   0         0                     0           0           0
# 17                   0         0                     0           0           0
# ...                ...       ...                   ...         ...         ...
# 74821                0         0                     0           0           0
# 74825                0         0                     0           0           0
# 74828                0         0                     0           0           0
# 74831                0         0                     0           0           0
# 74833                0         0                     0           0           0
#
# [31969 rows x 5457 columns]

# %% [markdown]
# Reindexamos:

# %%
steam_games_final.reset_index(drop=True, inplace=True)

# %% [markdown]
# Guardamos el dataset en un archivo parquet:

# %%
steam_games_final.to_parquet('steamgames_items_items.parquet')

# %% [markdown]
# Generamos el coeficiente del coseno:

# %%
similitud = cosine_similarity(steam_games_final.iloc[:,3:])

# %%
similitud.shape
# Out:
# (31969, 31969)

# %%
similitud
# Out:
# array([[1.        , 0.10259784, 0.18257419, ..., 0.        , 0.        ,
#         0.36514837],
#        [0.10259784, 1.        , 0.09365858, ..., 0.        , 0.        ,
#         0.09365858],
#        [0.18257419, 0.09365858, 1.        , ..., 0.23570226, 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.23570226, ..., 1.        , 0.23570226,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.23570226, 1.        ,
#         0.        ],
#        [0.36514837, 0.09365858, 0.        , ..., 0.        , 0.        ,
#         1.        ]])

# %% [markdown]
# Pasamos a DataFrame la matriz generada:

# %%
similitud_df = pd.DataFrame(similitud, index= steam_games['app_name'], columns=steam_games['app_name'])

# %%
similitud_df.head()
# Out:
# app_name                 Lost Summoner Kitty  Ironbound  \
# app_name
# Lost Summoner Kitty                 1.000000   0.102598
# Ironbound                           0.102598   1.000000
# Real Pool 3D - Poolians             0.182574   0.093659
# 弹炸人2222                             0.000000   0.000000
# Log Challenge                       0.000000   0.000000
#
# app_name                 Real Pool 3D - Poolians  弹炸人2222  Log Challenge  \
# app_name
# Lost Summoner Kitty                     0.182574  0.00000        0.00000
# Ironbound                               0.093659  0.00000        0.00000
# Real Pool 3D - Poolians                 1.000000  0.00000        0.00000
# 弹炸人2222                                 0.000000  1.00000        0.57735
# Log Challenge                           0.000000  0.57735        1.00000
#
# app_name                 Battle Royale Trainer  SNOW - All Access Basic Pass  \
# app_name
# Lost Summoner Kitty                   0.000000                      0.000000
# Ironbound                             0.000000                      0.114708
# Real Pool 3D - Poolians               0.000000                      0.204124
# 弹炸人2222                               0.408248                      0.000000
# Log Challenge                         0.176777                      0.500000
#
# app_name                 SNOW - All Access Pro Pass  \
# app_name
# Lost Summoner Kitty                        0.000000
# Ironbound                                  0.114708
# Real Pool 3D - Poolians                    0.204124
# 弹炸人2222                                    0.000000
# Log Challenge                              0.500000
#
# app_name                 SNOW - All Access Legend Pass  Race  ...  \
# app_name                                                      ...
# Lost Summoner Kitty                           0.000000   0.0  ...
# Ironbound                                     0.114708   0.0  ...
# Real Pool 3D - Poolians                       0.204124   0.0  ...
# 弹炸人2222                                       0.000000   0.0  ...
# Log Challenge                                 0.500000   0.0  ...
#
# app_name                 The spy who shot me™  Raining blocks  Bravium  BAE 2  \
# app_name
# Lost Summoner Kitty                  0.258199             0.0      0.0    0.0
# Ironbound                            0.132453             0.0      0.0    0.0
# Real Pool 3D - Poolians              0.000000             0.0      0.0    0.0
# 弹炸人2222                              0.666667             0.0      0.0    0.0
# Log Challenge                        0.288675             0.0      0.0    0.0
#
# app_name                 Kebab it Up!  Colony On Mars  \
# app_name
# Lost Summoner Kitty          0.000000        0.223607
# Ironbound                    0.000000        0.000000
# Real Pool 3D - Poolians      0.000000        0.000000
# 弹炸人2222                      0.516398        0.288675
# Log Challenge                0.670820        0.500000
#
# app_name                 LOGistICAL: South Africa  Russian Roads  \
# app_name
# Lost Summoner Kitty                      0.258199       0.000000
# Ironbound                                0.000000       0.000000
# Real Pool 3D - Poolians                  0.000000       0.235702
# 弹炸人2222                                  0.333333       0.000000
# Log Challenge                            0.577350       0.000000
#
# app_name                 EXIT 2 - Directions  Maze Run VR
# app_name
# Lost Summoner Kitty                      0.0     0.365148
# Ironbound                                0.0     0.093659
# Real Pool 3D - Poolians                  0.0     0.000000
# 弹炸人2222                                  0.0     0.235702
# Log Challenge                            0.0     0.000000
#
# [5 rows x 31969 columns]

# %% [markdown]
# Probamos un juego para tener una referencia cuando probemos nuestra función:

# %%
similitud_df['Shadow Ops: Red Mercury'].sort_values(ascending=False)
# Out:
# app_name
# Shadow Ops: Red Mercury                          1.000000
# Call of Duty®: Advanced Warfare - Season Pass    0.750000
# QUAKE II Mission Pack: The Reckoning             0.750000
# Project: Snowblind                               0.750000
# Call of Duty®: Ghosts - Wolf Skin                0.707107
#                                                    ...
# Space Geekz - The Crunchy Flakes Conspiracy      0.000000
# Speebot                                          0.000000
# Gold Rush: The Game                              0.000000
# BAFL - Brakes Are For Losers                     0.000000
# Maze Run VR                                      0.000000
# Name: Shadow Ops: Red Mercury, Length: 31969, dtype: float64

# %% [markdown]
# Ordenamos los indices de los juegos más similares de manera descendente, y luego seleccionamos los primeros 5:

# %%
similitud = np.argsort(-similitud, axis=1)[:, 1:6]

# %% [markdown]
# Guardamos lamatriz en un objeto Numpy Binario:

# %%
np.save('similitud.npy', similitud)

# %% [markdown]
# Creamos nuestra función:

# %%
def game_recomendation(id):
    cosine_sim = np.load('./similitud.npy')

    idx = steam_games_final[steam_games_final['id'] == float(id)].index[0]

    rec_indices = cosine_sim[idx]
    rec_games = steam_games_final.iloc[rec_indices]['app_name']

    print(f'TOP 5 juegos similares a {id}:')
    print('-----' * 8)

    recomendaciones = []  # Lista para almacenar las recomendaciones

    for count, game_id in enumerate(rec_games, start=1):
        recomendaciones.append(f'Número {count}: {game_id}')

        # Limitar a 5 recomendaciones
        if count == 5:
            break

# %% [markdown]
# Buscamos el **id** del juego que antes habiamos probado:

# %%
steam_games[steam_games['app_name'] == 'Shadow Ops: Red Mercury']
# Out:
#              id                 app_name                                  tags
# 68414  286770.0  Shadow Ops: Red Mercury  [Action, FPS, First-Person, Shooter]

# %% [markdown]
# Y podemos verificar que nuestro sistema de recomendación funciona perfectamente:

# %%
game_recomendation(286770)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ferna\Downloads\Proyecto 1 ML - Henry\ModeloRecomendacion.ipynb Celda 57 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ferna/Downloads/Proyecto%201%20ML%20-%20Henry/ModeloRecomendacion.ipynb#Y110sZmlsZQ%3D%3D?line=0'>1</a> recomendacion_juego(286770)
#
# c:\Users\ferna\Downloads\Proyecto 1 ML - Henry\ModeloRecomendacion.ipynb Celda 57 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/ferna/Downloads/Proyecto%201%20ML%20-%20Henry/ModeloRecomendacion.ipynb#Y110sZmlsZQ%3D%3D?line=0'>1</a> def recomendacion_juego(id):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ferna/Downloads/Proyecto%201%20ML%20-%20Henry/ModeloRecomendacion.ipynb#Y110sZmlsZQ%3D%3D?line=1'>2</a>     cosine_sim = np.load('./similitud.npy')
#       <a href='vscode-notebook-cell:/c%3A/Users/ferna/Downloads/Proyecto%201%20ML%20-%20Henry/ModeloRecomendacion.ipynb#Y110sZmlsZQ%3D%3D?line=3'>4</a>     idx = steam_games_final[steam_games_final['id'] == float(id)].index[0]
#       <a href='vscode-notebook-cell:/c%3A/Users/ferna/Downloads/Proyecto%201%20ML%20-%20Henry/ModeloRecomendacion.ipynb#Y110sZmlsZQ%3D%3D?line=5'>6</a>     rec_indices = cosine_sim[idx]
#
# NameError: name 'np' is not defined
